# %% [markdown]
# # **🪔 Project Name: Exploratory Data Analysis on Diwali Sales Data**

# %% [markdown]
# **Made By:** Dinesh Timande
#
# **Guided By:** Abhishek Wavhal

# %% [markdown]
# # **✨ Project Summary**

# %% [markdown]
# Diwali is one of the largest shopping festivals in India, where customers across demographics purchase products ranging from household items to electronics. Businesses often struggle to identify which customer segments, regions, and product categories contribute most to sales. Without data‑driven insights, marketing campaigns and inventory planning may fail to capture the full potential of festive demand.
#
# The goal of this project was to analyze Diwali festival sales data to uncover customer purchasing behavior, identify high‑value demographics, and highlight top‑performing products and regions. The insights can help businesses optimize marketing strategies and inventory planning during festive seasons.

# %% [markdown]
# # <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png" width="25" />  **GitHub Link**

# %% [markdown]
# Link: https://github.com/dineshtimande/Exploratory-Data-Analysis-on-Diwali-Sales-Data-using-Python

# %% [markdown]
# # **🎯Problem Statement**

# %% [markdown]
# The challenge is to transform raw Diwali sales data into actionable insights by cleaning, analyzing, and visualizing customer demographics, regional sales distribution, and product performance. The project must answer critical business questions:
# - Which customer segments (gender, age group, marital status, occupation) contribute most to sales?
# - Which states and zones generate the highest revenue during Diwali?
# - What are the top product categories and products driving festive demand?
# - How do orders and spending patterns vary across different demographics and regions?
# - How can businesses use these insights to optimize marketing, inventory, and festive strategies?

# %% [markdown]
# # **🚀 Let's Start !!**

# %% [markdown]
# # **🗂️ 1. Knowing your data**

# %% [markdown]
# ## **Importing Libaries required for the Project**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Loading dataset**

# %%
# So 'df' variable contains our data set
df = pd.read_csv("/content/drive/MyDrive/Pandas databases/Diwali Sales Data.csv", encoding="latin1")

# %% [markdown]
# ## **View of Dataset**

# %%
# Viewing first five records from the dataset

df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %% [markdown]
# ## **Count of Rows and Columns**

# %%
# Counting the rows and columns in the dataset

df.shape
# Out:
# (11251, 15)

# %%
# Kowing columns name

df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %% [markdown]
# ## **Dataset Information**

# %%
# Getting the information about the data set

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
# Getting the statistics calculation on all numerical columns

df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %% [markdown]
# ## **Duplicate Values**

# %%
# Knowing how many duplicate values are present in our dataset
duplicte_value = df.duplicated().value_counts()
duplicte_value
# Out:
# False    11243
# True         8
# Name: count, dtype: int64

# %%
plt.figure(figsize= (6,4))

dv= duplicte_value.plot(kind = 'bar', color = ["Purple", "deeppink"])
plt.title("Visualzation of duplicate value")
plt.ylabel("Duplicate value")
dv.bar_label(dv.containers[0], label_type= "edge")
plt.show()

# %% [markdown]
# From the above chart we can see that there are 8 dupicate values present in our dataset.

# %%
# Now lets drop the duplicate values

df.drop_duplicates(inplace = True)

# %%
# Knowing the count of records after droping the duplicates

df.shape[0]
# Out:
# 11243

# %%
# Now let's reset the index

df.reset_index()
# Out:
#        index  User_ID    Cust_name Product_ID Gender Age Group  Age  \
# 0          0  1002903    Sanskriti  P00125942      F     26-35   28
# 1          1  1000732       Kartik  P00110942      F     26-35   35
# 2          2  1001990        Bindu  P00118542      F     26-35   35
# 3          3  1001425       Sudevi  P00237842      M      0-17   16
# 4          4  1000588         Joni  P00057942      M     26-35   28
# ...      ...      ...          ...        ...    ...       ...  ...
# 11238  11246  1000695      Manning  P00296942      M     18-25   19
# 11239  11247  1004089  Reichenbach  P00171342      M     26-35   33
# 11240  11248  1001209        Oshin  P00201342      F     36-45   40
# 11241  11249  1004023       Noonan  P00059442      M     36-45   37
# 11242  11250  1002744      Brumley  P00281742      F     18-25   19
#
#        Marital_Status           State      Zone       Occupation  \
# 0                   0     Maharashtra   Western       Healthcare
# ...

# %% [markdown]
# ## **Finding missing value**

# %%
# Finding missing values or null values
df.isnull() == True
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
# Now let's replace the null values with 'NaN'

df.fillna(np.nan, inplace= True)

# %%
# Visualizing the null values

a= df.isna().sum()
null_values = a.sort_values(ascending= False)[:5]
null_values
# Out:
# Status      11243
# unnamed1    11243
# Amount         12
# Gender          0
# User_ID         0
# dtype: int64

# %%
plt.figure(figsize=(6,4))
null_values.plot(kind = "bar", color='deeppink' )
plt.title("Visualization of null values")
plt.ylabel("Count of null values")
plt.xlabel("Rows")
plt.xticks(rotation = 35)
plt.show()

# %% [markdown]
# ## **About dataset**
#
# 1. In total we got to know that we have 11251 columns and 15 rows in our data set.
#
# 2. Total duplicates values count is of 8.
#
# 3. After removing duplicates we got 11243 cleaned records
#
# 4. There are three columns in dataset that has the null values they are Satus, unnamed1, Amount.
#
# 5. So from above observation it specify that status and unnamed1 columns are completely blank column so we can remove these columns.

# %%
# Getting the information about the data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11243 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11243 non-null  int64
#  1   Cust_name         11243 non-null  object
#  2   Product_ID        11243 non-null  object
#  3   Gender            11243 non-null  object
#  4   Age Group         11243 non-null  object
#  5   Age               11243 non-null  int64
#  6   Marital_Status    11243 non-null  int64
#  7   State             11243 non-null  object
#  8   Zone              11243 non-null  object
#  9   Occupation        11243 non-null  object
#  10  Product_Category  11243 non-null  object
#  11  Orders            11243 non-null  int64
#  12  Amount            11231 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.4+ MB

# %% [markdown]
# # **🧠2. Understanding your Variable**

# %%
# Viewing datasets columns
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
# Describing the data including all columns
df.describe(include= 'all')
# Out:
#              User_ID Cust_name Product_ID Gender Age Group           Age  \
# count   1.124300e+04     11243      11243  11243     11243  11243.000000
# unique           NaN      1250       2351      2         7           NaN
# top              NaN  Vishakha  P00265242      F     26-35           NaN
# freq             NaN        42         53   7838      4538           NaN
# mean    1.003005e+06       NaN        NaN    NaN       NaN     35.422841
# std     1.716141e+03       NaN        NaN    NaN       NaN     12.756369
# min     1.000001e+06       NaN        NaN    NaN       NaN     12.000000
# 25%     1.001494e+06       NaN        NaN    NaN       NaN     27.000000
# 50%     1.003065e+06       NaN        NaN    NaN       NaN     33.000000
# 75%     1.004430e+06       NaN        NaN    NaN       NaN     43.000000
# max     1.006040e+06       NaN        NaN    NaN       NaN     92.000000
#
#         Marital_Status          State     Zone Occupation    Product_Category  \
# ...

# %% [markdown]
# ## **Variable description**
#
# 1. User_ID = Primary Key it will identify every record uniquely.
#
# 2. Cust_name = Column contains the name of the customers.
#
# 3. Product_ID = Unique product ID for different Products.
#
# 4. Gender = It specifies the gender of the customer.
#
# 5. Age Group = This column divided ages in to particular groups.
#
# 6. Age = This column contains the age of the customers.
#
# 7. Marital_status = This columns specifies if the customer is married or not.
#
# 8. State = This column specify the state name.
#
# 9. Zone = This column specify the zone name.
#
# 10. Occupation = This column specify the occupation of the customers.
#
# 11. Product_category = This column specify  the category of the product.
#
# 12. Orders = this column specify how many orders.
#
# 13. Amount = This column specify the amount of the product purchased.

# %%
# Check Unique values in each column
# Each column unique values will be describe by lambda
from enum import unique
a = df.apply(lambda col: col.unique())
print(a)
# Out:
# User_ID             [1002903, 1000732, 1001990, 1001425, 1000588, ...
# Cust_name           [Sanskriti, Kartik, Bindu, Sudevi, Joni, Balk,...
# Product_ID          [P00125942, P00110942, P00118542, P00237842, P...
# Gender                                                         [F, M]
# Age Group              [26-35, 0-17, 18-25, 55+, 46-50, 51-55, 36-45]
# Age                 [28, 35, 16, 25, 61, 26, 34, 20, 46, 24, 48, 2...
# Marital_Status                                                 [0, 1]
# State               [Maharashtra, Andhra Pradesh, Uttar Pradesh, K...
# Zone                  [Western, Southern, Central, Northern, Eastern]
# Occupation          [Healthcare, Govt, Automobile, Construction, F...
# Product_Category    [Auto, Hand & Power Tools, Stationery, Tupperw...
# Orders                                                   [1, 3, 2, 4]
# Amount              [23952.0, 23934.0, 23924.0, 23912.0, 23877.0, ...
# ...

# %% [markdown]
# # **🛠️3. Data Wrangling**

# %%
# We will make the copy of our clean data

df1 = df.copy()

# %%
# Drop completely empty columns
df1 = df1.drop(columns=['Status', 'unnamed1'])

# %%
# Handle missing values in 'Amount'
df1['Amount'] = df1['Amount'].fillna(0)

# %%
#previewing 5 column from dataset after deleting column.
df1.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %% [markdown]
# ## **Manipulations made in data**
#
# 1. Removed column named Status
#
# 2. Removed column named Unnamed1
#
# 3. Dealed with the missing values in the Amount column and replaced it with '0'.

# %% [markdown]
# # **📊4. Data Visualization and Story Telling**

# %% [markdown]
# ## **Chart 1**
#
# Question 1. - Which gender contributed more to overall revenue?

# %%
plt.figure(figsize=(6,4))
ax = sns.barplot(x='Gender', y='Amount', data=df1, estimator= sum)
plt.title("Total Sales by Gender")
ax.bar_label(ax.containers[0], fmt = "%0.0f")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Bar chart was used as there were only two category(Male and Female), so it is easy to check and understand the gender type and revenue contribution.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that female contributed more in generating the revenue.
#
#
# **3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.**
#
# Stores will have to also focus on the different ways to attract males for revenue contribution.
#
# So Yes, gained insights help creating a positive business impact.

# %% [markdown]
# ## **Chart 2**
#
# Question 2. Which age group spent the most during Diwali?

# %%
plt.figure(figsize=(6,4))
sns.barplot(x='Age Group', y='Amount', data=df1, estimator=sum)
plt.title("Total Sales by Age Group")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Bar chart was used as it is easy to check and understand the age group and their revenue contribution.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that age group (26-35) contributed more in generating the revenue.
#
#
# **3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.**
#
# Stores will have to also focus on the different ways to attract all age groups for revenue contribution.
#
# So Yes, gained insights help creating a positive business impact.

# %% [markdown]
# ## **Chart 3**
#
# Question 3. Do married customers spend more than unmarried ones?

# %%
plt.figure(figsize=(6,4))
ax = sns.barplot(x='Marital_Status', y='Amount', data=df1, estimator='mean')
plt.title("Average Spending by Marital Status")
ax.bar_label(ax.containers[0], fmt = "%0.0f")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Bar chart was used as it is easy to check and understand the marital status and their revenue contribution.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that married people contributed more in generating the revenue.
#
#
# **3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.**
#
# Stores will have to also focus on the different ways to attract unmarried people for revenue contribution.
#
# So Yes, gained insights help creating a positive business impact.

# %% [markdown]
# ## **Chart 4**
#
# Question 4. Which professions contributed the highest revenue?

# %%
plt.figure(figsize=(9,6))
sns.barplot(y='Occupation', x='Amount', data=df1, estimator=sum)
plt.title("Total Sales by Occupation")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Horizontal Bar chart was used as it is easy to check and understand the occupation and their revenue contribution.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that IT, Healthcare, and Business professionals dominate sales.
#
#
# **3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.**
#
# Stores will have to also focus on the different ways to attract all people from different occupation like (agriculture , construction )for revenue contribution.
#
# So Yes, gained insights help creating a positive business impact.

# %% [markdown]
# ## **Chart 5**
#
# Question 5. Is there a correlation between age and number of orders placed ?

# %%
plt.figure(figsize=(9,6))
sns.scatterplot(x='Age', y='Orders', data=df1)
plt.title("Age vs Orders")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Scatter Plot chart was used as it is easy to check and understand relationship between two numerical column.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that younger customers (20–35) place more orders.
#
#
# **3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.**
#
# Stores will have to also focus on the different ways to attract all age group people for revenue contribution.
#
# So Yes, gained insights help creating a positive business impact.

# %% [markdown]
# ## **Chart 6**
#
# Question 6. Which states generated the highest revenue?

# %%
state_sales = df1.groupby('State')['Amount'].sum().sort_values(ascending=False).head(10)
sns.barplot(x=state_sales.index, y=state_sales.values)
plt.xticks(rotation=45)
plt.title("Top States by Sales")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Bar chart was used as it is easy to check and understand states and their contribution to the revenue.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that Uttar Pradesh, Maharashtra, and Karnataka are the leading states

# %% [markdown]
# ## **Chart 7**
#
# Question 7. Which zone (North, South, East, West) dominated festive sales?

# %%
zone_sales = df1.groupby('Zone')['Amount'].sum()
zone_sales.plot(kind='pie', autopct='%1.1f%%')
plt.title("Sales by Zone")
plt.ylabel("")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Pie chart was used as it is easy to check and understand zones and their contribution to the revenue.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that North Zone contributes the highest share.

# %% [markdown]
# ## **Chart 8**
#
# Question 8. Which states had the highest number of orders placed?

# %%
state_orders = df1.groupby('State')['Orders'].sum().sort_values(ascending=False).head(10)
sns.barplot(x=state_orders.index, y=state_orders.values)
plt.xticks(rotation=45)
plt.title("Top States by Orders")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Bar chart was used as it is easy to check and understand states and their total orders.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that there is High order volume in UP and Maharashtra.

# %% [markdown]
# ## **Chart 9**
#
# Question 9. Which product categories were most popular?

# %%
sns.barplot(x='Product_Category', y='Amount', data=df1, estimator=sum)
plt.xticks(rotation=90)
plt.title("Sales by Product Category")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Bar chart was used as it is easy to check and understand product category and there sales.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that Electronics and Household items dominate.

# %% [markdown]
# ## **Chart 10**
#
# Question 10. Which individual products generated the most revenue?

# %%
top_products = df1.groupby('Product_ID')['Amount'].sum().sort_values(ascending=False).head(10)
sns.barplot(x=top_products.index, y=top_products.values)
plt.xticks(rotation=45)
plt.title("Top 10 Products by Revenue")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Bar chart was used as it is easy to check and understand product and their generated revenue.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that ProductID (P00265242 , P001110942 , P00184942) generated most of the revenue.

# %% [markdown]
# ## **Chart 11**
#
# Question 11. Do categories with more orders also generate higher revenue?

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x='Orders', y='Amount', hue='Product_Category', data=df1)
plt.title("Orders vs Amount by Product Category")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Scatter plot chart was used as it is easy to check and understand relation between two numerical variable.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that
#
# - Electronics → fewer orders but very high Amount values (points high on Y‑axis).
# - Household items → more orders with moderate spending (points spread across X‑axis).
# - Other categories → scattered patterns depending on popularity and price.

# %% [markdown]
# ## **Chart 12**
#
# Question 12. Which categories have the highest average spend per order?

# %%
avg_order_value = df1.groupby('Product_Category')['Amount'].mean().sort_values(ascending=False)
sns.barplot(x=avg_order_value.index, y=avg_order_value.values)
plt.xticks(rotation=90)
plt.title("Average Order Value by Category")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Bar chart was used as it is easy to check and understand categories and the highest average spend per order.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Based on the above observations, It is found that Auto ,Tupperware, Had and Power Tools have highest average spend per order.

# %% [markdown]
# ## **Chart 13**
#
# Question 13. Is revenue driven by many small orders or fewer large purchases

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Orders', y='Amount', data=df1)
plt.title("Orders vs Amount")
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Scatter plot chart was used as it is easy to check and understand relation between two numerical variable.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Above chart Shows whether revenue comes from many small orders or fewer large ones.

# %% [markdown]
# ## **Chart 14**
#
# Question 14. Combine gender, age group, and occupation into a multi‑facet visualization to identify the most profitable customer segment.

# %%
g = sns.catplot(x='Age Group', y='Amount', hue='Gender', col='Occupation',
                data=df1, kind='bar', estimator=sum, col_wrap=3)
g.fig.suptitle("Customer Segment Comparison", y=1.05)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**
#
# Catplot chart was used as it is easy to check and understand relation between multiple variable.
#
# **2. What is/are the insight(s) found from the chart?**
#
# Above chart Reveals the most profitable segment: Married women aged 26–35 in IT/Business occupations.

# %% [markdown]
# # **🏨Recommendations / Solutions**

# %% [markdown]
# **🎯Marketing**
# - Focus on women: Since female customers contributed the highest share of sales, campaigns should highlight products that resonate with them—fashion, household essentials, lifestyle bundles. Personalized offers (e.g., “Festive Home Makeover Kits”) can drive engagement.
# - **Millennials (26–35 age group)**: This group dominated spending. They are digital‑savvy, so social media ads, influencer collaborations, and app‑based promotions will maximize reach.
# - **Married professionals**: Married customers spend more, especially in IT, Healthcare, and Business occupations. Position premium products (electronics, appliances) as family investments.
# - **Impact**: Marketing becomes sharper, targeting the most profitable demographics instead of broad, unfocused campaigns.
#
# **📦Inventory**
# - **Electronics**: High average order value and revenue contribution. Stock premium electronics (smartphones, laptops, appliances) in advance.
# - **Household items**: High order volume, moderate revenue. These are “fast‑moving” festive essentials. Ensure bulk availability to avoid stockouts.
# - **High‑demand states (UP, Maharashtra, Karnataka)**: Allocate more inventory to regional warehouses in these states. This reduces delivery delays and ensures supply meets demand.
# - **Impact**: Inventory planning aligns with actual demand patterns, minimizing overstock in low‑demand regions and shortages in high‑demand ones.
#
# **🚀 Sales Strategy**
# - Geo‑targeted ads: Use state‑level insights (UP, Maharashtra, Karnataka) to run localized campaigns. Example: “Exclusive Diwali Deals for Maharashtra Customers.”
# - **Festive bundles**: Combine high‑volume household items with high‑value electronics. Example: “Smartphone + Kitchen Essentials Combo.” This drives cross‑selling.
# - **Financing schemes**: Millennials and professionals are willing to spend more if flexible payment options exist. EMI, cashback, and festive credit cards can boost premium product sales.
# - **Impact**: Sales campaigns become more persuasive, balancing affordability with aspirational purchases.
#
# 📱 **Customer Experience**
# - **Mobile shopping optimization**: Younger customers place more orders, often via mobile. Ensure app UX is smooth, with one‑click checkout and personalized recommendations.
# - **Delivery speed**: High order volumes in certain states require faster logistics. Partner with local couriers, expand last‑mile delivery, and offer “Same‑Day Festive Delivery” in metros.
# - **Post‑purchase engagement**: Send personalized thank‑you messages, festive greetings, and loyalty points to encourage repeat purchases.
# - **Impact**: Customers feel valued, enjoy seamless shopping, and are more likely to return for future festive seasons.

# %% [markdown]
# ##🏁 **Conclusion**

# %% [markdown]
# The Diwali Sales Data project successfully transformed raw transactional records into meaningful business insights.
#
# Through systematic data cleaning, exploratory analysis, and visualization, the study revealed clear patterns in customer demographics, regional demand, and product performance.
# - Customer Insights: Women, millennials (26–35), and married professionals emerged as the most profitable segments, highlighting the importance of targeted marketing.
# - Regional Insights: Uttar Pradesh, Maharashtra, and Karnataka, particularly in the North Zone, contributed the highest revenue, underscoring the need for geo‑focused campaigns and inventory allocation.
# - Product Insights: Electronics and household items dominated festive purchases, with electronics driving high‑value transactions and household items driving high‑volume sales.
# - Behavioral Insights: Revenue was generated both from frequent small orders and fewer large purchases, suggesting businesses should cater to both budget and premium buyers.
#
#
# By connecting these findings to strategic recommendations—such as women‑centric marketing, regional inventory prioritization, festive bundles, and mobile‑optimized shopping—the project demonstrates how data can directly inform business decisions.

# %% [markdown]
# # **- - - - - - - Thank you !!- - - - - - -**
